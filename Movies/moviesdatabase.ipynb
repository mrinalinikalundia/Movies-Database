# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:\\Users\\Machine Learning\\moviesdatabase.txt',engine='python',names=(['EId','MovieName','Year','Ratings','Duration']))

# %%
from IPython.display import display

# %%
display(df)
# Out:
#          EId                                          MovieName  Year  \
# 0          1                     The Nightmare Before Christmas  1993
# 1          2                                          The Mummy  1932
# 2          3                               Orphans of the Storm  1921
# 3          4                               The Object of Beauty  1991
# 4          5                                         Night Tide  1963
# ...      ...                                                ...   ...
# 49585  49586                                  Winter Wonderland  2013
# 49586  49587                Top Gear: Series 19: Africa Special  2013
# 49587  49588  Fireplace For Your Home: Crackling Fireplace w...  2010
# 49588  49589                                    Kate Plus Ei8ht  2010
# 49589  49590                          Kate Plus Ei8ht: Season 1  2010
#
#        Ratings  Duration
# 0          3.9    4568.0
# 1          3.5    4388.0
# 2          3.2    9062.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49590 entries, 0 to 49589
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   EId        49590 non-null  int64
#  1   MovieName  49590 non-null  object
#  2   Year       49590 non-null  int64
#  3   Ratings    10814 non-null  float64
#  4   Duration   45836 non-null  float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 1.7+ MB

# %%
df["Ratings"].fillna(df["Ratings"].mean(),inplace=True )

# %%
df["Duration"].fillna(df["Duration"].mean(),inplace=True )

# %%
df.drop(['EId'], axis=1,inplace=True)

# %%
df.Year.nunique()
# Out:
# 101

# %%
dataset=df.iloc[:50000,:]
print(dataset.shape)
# Out:
# (49590, 4)

# %%
df[df.Duration>7200]
# Out:
#                                                MovieName  Year  Ratings  \
# 2                                   Orphans of the Storm  1921      3.2
# 12                                 The Birth of a Nation  1915      2.9
# 13                                  The Boys from Brazil  1978      3.6
# 20                            Born on the Fourth of July  1989      3.4
# 21                                        Broadcast News  1987      3.4
# ...                                                  ...   ...      ...
# 45107                                             Settai  2013      2.8
# 46831  WWE for All Mankind: The Life &#38; Career of ...  2013      4.2
# 46948                     Example Short XII 23976 2 Hour  2010      2.6
# 48713     WWE: The Top 25 Rivalries in Wrestling History  2013      3.7
# 49054                       Theeya Velai Seyyanum Kumaru  2013      3.3
#
#        Duration
# 2        9062.0
# 12      12118.0
# 13       7417.0
# 20       8646.0
# ...

# %%
df[df.Ratings>4.0]
# Out:
#                                                MovieName  Year  Ratings  \
# 138                                         Pulp Fiction  1994      4.1
# 287                                    Life Is Beautiful  1997      4.2
# 302                               Mulan: Special Edition  1998      4.2
# 464                                         Forrest Gump  1994      4.3
# 490                                           Braveheart  1995      4.2
# ...                                                  ...   ...      ...
# 49548                           Life With Boys: Season 1  2011      4.1
# 49553                                          Max Steel  2013      4.1
# 49555                       Lilyhammer: Season 1 (Recap)  2013      4.2
# 49570                           The Short Game (Trailer)  2013      4.1
# 49578  Transformers Prime Beast Hunters: Predacons Ri...  2013      4.2
#
#            Duration
# 138     9265.000000
# 287     6973.000000
# 302     5270.000000
# ...

# %%
df[(df.Year>=1900)&(df.Year<=1920)]
# Out:
#                                                MovieName  Year   Ratings  \
# 10                                       Broken Blossoms  1919  3.300000
# 12                                 The Birth of a Nation  1915  2.900000
# 61                               Dr. Jekyll and Mr. Hyde  1920  3.200000
# 78                                     The Mark of Zorro  1920  3.100000
# 188                                        Way Down East  1920  3.000000
# 368                                          Intolerance  1916  3.200000
# 609                                              Cabiria  1914  2.900000
# 2743                                   One Arabian Night  1920  2.500000
# 2744                                         Anna Boleyn  1920  2.400000
# 14327                 Fantômas III: The Murderous Corpse  1913  2.600000
# 20052  Charlie Chaplin Collection: Shorts: The Champi...  1914  3.451248
# 20053  Charlie Chaplin Collection: Shorts: The Immigr...  1914  3.451248
# ...

# %%
df.iloc[:, 0]
# Out:
# 0                           The Nightmare Before Christmas
# 1                                                The Mummy
# 2                                     Orphans of the Storm
# 3                                     The Object of Beauty
# 4                                               Night Tide
#                                ...
# 49585                                    Winter Wonderland
# 49586                  Top Gear: Series 19: Africa Special
# 49587    Fireplace For Your Home: Crackling Fireplace w...
# 49588                                      Kate Plus Ei8ht
# 49589                            Kate Plus Ei8ht: Season 1
# Name: MovieName, Length: 49590, dtype: object

# %%
group_data=df.groupby('Year')
print(group_data)

# %%
df.groupby(['Duration','Year']).mean()
# Out:
#                Ratings
# Duration Year
# 52.0     2012      3.6
# 55.0     2012      3.3
# 66.0     2012      3.3
# 67.0     2013      3.1
# 69.0     2012      3.6
# ...                ...
# 13143.0  1980      3.0
# 16422.0  1922      3.1
# 16736.0  2010      2.3
# 22024.0  2003      3.9
# 28813.0  2010      3.1
#
# [20301 rows x 1 columns]

# %%
df.groupby(['Ratings','Year']).mean()
# Out:
#                  Duration
# Ratings Year
# 1.4     2007  2628.445436
# 1.5     2011  2628.445436
# 1.6     1984  4937.000000
#         2004  2628.445436
#         2008  2628.445436
# ...                   ...
# 4.5     2009  2628.445436
#         2010  2628.445436
#         2011  2628.445436
#         2012  4115.084077
#         2013  2243.111678
#
# [1345 rows x 1 columns]

# %%
x=df['Year']
y=df['Ratings']

# %%
bins=[1900,1920,1940,1960,1980,2000,2020]
plt.hist(x, bins=bins,edgecolor='black',log=True)
plt.title('Total Movies per year')
plt.ylabel('no of values')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')
